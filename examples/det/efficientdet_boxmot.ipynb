# %%
pip install effdet

# %%
import cv2
import torch
from effdet import create_model
from effdet.config import get_efficientdet_config
from torchvision import transforms

from boxmot import create_tracker
from boxmot.structures import Boxes, Detections
from boxmot.trackers import TrackerSpec

# Load EfficientDet model
device = torch.device('mps')  # Use 'cuda' if you have a GPU

model_name = 'tf_efficientdet_d0'  # You can choose a different variant like 'tf_efficientdet_d3'
config = get_efficientdet_config(model_name)
model = create_model(model_name, bench_task='predict', pretrained=True).to(device)
model.eval()

# Initialize the tracker
tracker = create_tracker(TrackerSpec(name='bytetrack', geometry='aabb'))

input_size = config.image_size

preprocess = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Open the video file
vid = cv2.VideoCapture(0)  # or 'path/to/your.avi'
frame_index = 0

while True:
    # Capture frame-by-frame
    ret, frame = vid.read()

    # If ret is False, it means we have reached the end of the video
    if not ret:
        break

    # Resize explicitly at this external detector boundary
    input_height, input_width = input_size
    scale_x = input_width / frame.shape[1]
    scale_y = input_height / frame.shape[0]
    resized_frame = cv2.resize(frame, (input_width, input_height))

    # Preprocess frame for EfficientDet (resize and normalize)
    frame_tensor = preprocess(resized_frame).unsqueeze(0).to(device)

    # Perform detection
    with torch.no_grad():
        detections = model(frame_tensor)[0]

    # Assuming detections is shaped [100, 6], with [x1, y1, x2, y2, confidence, class]
    confidence_threshold = 0.5

    # Filter detections based on confidence threshold
    mask = detections[:, 4] >= confidence_threshold
    filtered_dets = detections[mask]

    # Rescale coordinates back to the original frame size
    filtered_dets[:, [0, 2]] /= scale_x
    filtered_dets[:, [1, 3]] /= scale_y

    # Convert once at the detector boundary into canonical CPU tensors
    rows = filtered_dets.to(device='cpu', dtype=torch.float32).contiguous()
    detections = Detections(
        geometry=Boxes(rows[:, :4].contiguous()),
        scores=rows[:, 4].contiguous(),
        class_ids=rows[:, 5].to(dtype=torch.int64).contiguous(),
        sample_id=f'camera-0:{frame_index:012d}',
    )
    tracks = tracker.update(detections)

    # Plot tracking results on the image
    for box, track_id in zip(tracks.geometry.values.round().to(torch.int64).tolist(), tracks.track_ids.tolist()):
        cv2.rectangle(frame, box[:2], box[2:], (0, 255, 0), 2)
        cv2.putText(frame, str(track_id), box[:2], cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    frame_index += 1

    # Display the frame
    cv2.imshow('BoXMOT + EfficientDet', frame)

    # Simulate wait for key press to continue, press 'q' to exit
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break

# Release resources
vid.release()
cv2.destroyAllWindows()
